# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
# read the loss data
#train_loss_simple = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/BBBDenseRegression/train_loss.npy')
##test_loss_simple = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/BBBDenseRegression/test_loss.npy')
#val_loss_simple = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/BBBDenseRegression/val_loss.npy')

#train_loss_dense = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/DenseRegression/train_loss.npy')
#test_loss_dense = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/DenseRegression/test_loss.npy')
#val_loss_dense = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/DenseRegression/val_loss.npy')

train_loss_BBB = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/BBBDenseRegression/train_loss.npy')
test_loss_BBB = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/BBBDenseRegression/test_loss.npy')
val_loss_BBB = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/BBBDenseRegression/val_loss.npy')

# %%
# plot the loss data
fig, ax = plt.subplots(1, 3, figsize=(10, 6))
# make x_axis 5000
sns.set()
ax[0].plot(test_loss_simple, label='test loss')
ax[0].plot(val_loss_simple, label='validation loss')
ax[0].set_title('Simple Dense Model')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Loss')
ax[0].legend()

ax[1].plot(test_loss_dense, label='test loss')
ax[1].plot(val_loss_dense, label='validation loss')
ax[1].set_title('Dense Model')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Loss')
ax[1].legend()

ax[2].plot(test_loss_BBB, label='test loss')
ax[2].plot(val_loss_BBB, label='validation loss')
ax[2].set_title('Bayesian Dense Model')
ax[2].set_xlabel('Epoch')
ax[2].set_ylabel('Loss')
ax[2].legend()

plt.tight_layout()

# %%
# plot loss data for BBB
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
#gs = ax.get_gridspec()



# make x_axis
ax.plot(test_loss_BBB, label='test loss')
ax.plot(val_loss_BBB, label='validation loss')
ax.set_title('Bayes By Backprop Dense Model')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.legend()

# zoom in on the last 100 epochs
 # zoom = 2

with sns.axes_style("dark"):
    x1, x2, y1, y2 = 1850, 1900, 8600, 9150
    axins = ax.inset_axes([0.6, 0.6, 0.3, 0.3]) 
    axins.plot(test_loss_BBB, label='test loss')
    axins.plot(val_loss_BBB, label='validation loss')
    axins.set_xlim(x1, x2)
    axins.set_ylim(y1, y2)
    axins.set_title('Zoomed in on the last 50 epochs')
    axins.set_xlabel('Epoch Zoomed in on 1850-1900 epochs')
    # ylabel on the right side
    axins.set_ylabel('Loss Zoomed in')

    axins.yaxis.set_label_position("right")
   


    

    ax.indicate_inset_zoom(axins)

    # set axins title
    axins.set_title('Zoomed in on the epochs 1850-1900')

    axins.legend()













# mark the region corresponding to the inset axes on ax1 and draw lines










plt.tight_layout()

# %%
# read the true vs predicted data
true_simple = np.load('//Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/SimpleFFBNN/true.npy')
pred_simple = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/SimpleFFBNN/preds.npy')

true_dense = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/DenseRegression/true.npy')
pred_dense = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/DenseRegression/preds.npy')

true_BBB = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/BBBDenseRegression/true.npy')
pred_BBB = np.load('/Users/kristian/Documents/Skole/9. Semester/Thesis Preparation/Code/BNNs/ThesisPlots/Results/Regression/BBBDenseRegression/preds.npy')

# plot the true vs predicted data
sns.distplot(true_simple, hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3}, label = 'True Values')
sns.distplot(pred_simple, hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3}, label = 'Predicted Values')
plt.xlabel('Values')
plt.ylabel('Density')
plt.title('True vs Predicted values')
plt.legend()
plt.show()

sns.distplot(true_dense, hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3}, label = 'True Values')
sns.distplot(pred_dense, hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3}, label = 'Predicted Values')
plt.xlabel('Values')
plt.ylabel('Density')
plt.title('True vs Predicted values')
plt.legend()
plt.show()

sns.distplot(true_BBB, hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3}, label = 'True Values')
sns.distplot(pred_BBB, hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3}, label = 'Predicted Values')
plt.xlabel('Values')
plt.ylabel('Density')
plt.title('True vs Predicted values')
plt.legend()
plt.show()

# put all the plots in one figure

fig, ax = plt.subplots(3, 3, figsize=(10, 10))

ax[0, 0].plot(test_loss_simple, label='test loss')
ax[0, 0].plot(val_loss_simple, label='validation loss')
ax[0, 0].set_title('Simple Dense Model')
ax[0, 0].set_xlabel('Epoch')
ax[0, 0].set_ylabel('Loss')
ax[0, 0].legend()

ax[0, 1].plot(test_loss_dense, label='test loss')
ax[0, 1].plot(val_loss_dense, label='validation loss')
ax[0, 1].set_title('Dense Model')
ax[0, 1].set_xlabel('Epoch')
ax[0, 1].set_ylabel('Loss')
ax[0, 1].legend()

ax[0, 2].plot(test_loss_BBB, label='test loss')
ax[0, 2].plot(val_loss_BBB, label='validation loss')
ax[0, 2].set_title('Bayesian Dense Model')
ax[0, 2].set_xlabel('Epoch')
ax[0, 2].set_ylabel('Loss')
ax[0, 2].legend()
# Out:
# /Users/kristian/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/kristian/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/kristian/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/kristian/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/kristian/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/kristian/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/kristian/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/kristian/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/kristian/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/kristian/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/kristian/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/kristian/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# function to isolate the colors from viridis
viridis_colors = sns.color_palette("viridis", 6)
def isolate_viridis_colors(viridis_colors):
    new_colors = []
    for i in range(0, 6):
        new_colors.append(viridis_colors[i])
    return new_colors

viridis_colors = isolate_viridis_colors(viridis_colors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f5d514fefb65> in <module>
#       1 # function to isolate the colors from viridis
# ----> 2 viridis_colors = sns.color_palette("viridis", 6)
#       3 def isolate_viridis_colors(viridis_colors):
#       4     new_colors = []
#       5     for i in range(0, 6):
#
# NameError: name 'sns' is not defined

# %%
# plot the true vs predicted data
fig, ax = plt.subplots(1, 3, figsize=(10, 10))

# give the figure a title
fig.suptitle('True vs Predicted Values for Regression Models')

sns.distplot(true_simple, hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3}, label = 'True Values', ax=ax[0], color=color2)
sns.distplot(pred_simple, hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3}, label = 'Predicted Values', ax=ax[0], color=color2)
ax[0].set_xlabel('Values')
ax[0].set_ylabel('Density')
ax[0].set_title('Simple Closed Form Model')
ax[0].legend()

sns.distplot(true_dense, hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3}, label = 'True Values', ax=ax[1], color=color1)
sns.distplot(pred_dense, hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3}, label = 'Predicted Values', ax=ax[1], color=color2)
ax[1].set_xlabel('Values')
ax[1].set_ylabel('Density')
ax[1].set_title('Dense Closed Form Model')
ax[1].legend()

sns.distplot(true_BBB, hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3}, label = 'True Values', ax=ax[2], color=color1)
sns.distplot(pred_BBB, hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3}, label = 'Predicted Values', ax=ax[2], color=color2)
ax[2].set_xlabel('Values')
ax[2].set_ylabel('Density')
ax[2].set_title('Bayes By Backprop Model')
ax[2].legend()

plt.tight_layout()
# Out:
# /Users/kristian/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-87ba7e1843bd> in <module>
#       5 fig.suptitle('True vs Predicted Values for Regression Models')
#       6
# ----> 7 sns.distplot(true_simple, hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3}, label = 'True Values', ax=ax[0], color=color2)
#       8 sns.distplot(pred_simple, hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3}, label = 'Predicted Values', ax=ax[0], color=color2)
#       9 ax[0].set_xlabel('Values')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2624         kde_color = kde_kws.pop("color", color)
#    2625         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
# -> 2626         if kde_color != color:
#    2627             kde_kws["color"] = kde_color
#    2628
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
print(true_simple.shape)
# Out:
# (64, 1)
